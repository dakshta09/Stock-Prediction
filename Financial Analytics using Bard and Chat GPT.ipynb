# %%
#importing libraries
import pprint
import google.generativeai as palm
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import openai
import os
from flask import Flask, render_template, request

# %%
#add your api key here
palm.configure(api_key='AIzaSyDqErL4GIRikBNqN6n3qggnR4mNMw8w6p4')

# %%
#chatgpt configuration
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_key = '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'

# %%
# We are working with Generate Text model only
models = [m for m in palm.list_models() if 'generateText' in m.supported_generation_methods]
model = models[0].name

# %%
#function to call bard api and get prompt response
def palmresponse(prompt):
    completion = palm.generate_text(
    model=model,
    prompt=prompt,
    temperature=0,
    max_output_tokens=2000)

    return completion.result

# %%
def gpt_outcome_data(message):    
    response = openai.Completion.create(
    engine='text-davinci-003',#"text-embedding-ada-002",  
    prompt=message,
    max_tokens=2000,
    n=1,
    stop=None)
    return response.choices[0].text.strip()

# %% [markdown]
# ## Case 1- Using Bard and ChatGPT to extract the financial data and performing analytics based on that data

# %%
# function to convert the string output to pandas dataframe
def debtequitydf(bard):
    import sys
    if sys.version_info[0] < 3: 
        from StringIO import StringIO
    else:
        from io import StringIO

    TESTDATA = StringIO(bard)
    df = pd.read_csv(TESTDATA, sep="|")
    return df.iloc[1:,1:-1]

# %%
#function to generate prompt for different companies
def bardoutcome_data(company,type1):
    #add your prompt here
    prompt ="fetch the data for fields- total debt, total equity, total debt on total equity, diluted eps, total revenue,\
    net income, EBITDA,Long Term Investment,Interest Expense,Return on Equity,Cash \
    and Cash Equivalents ,Quick Ratio,Current Ratio  for "+company + "from FY 2020 to 2022 and  \
    triple checked this data and it is all consistent across\
    Google Finance, Yahoo Finance, and Investing.com."
    if type1=='Bard':
        response=palmresponse(prompt)
    elif type1=='ChatGpt':
        #print(prompt)
        response=gpt_outcome_data(prompt)
        #print(response)
    return response

# %%
#function to generate prompt for different companies
def bardoutcome_investment(company, data,type1):
    #add your prompt here
    prompt ="Is "+company+" a good company to invest in 2023 and how much % return someone can expect to get on $1000. \
    Use this data to analyze - Total Debt,Total Equity,Total Debt on Total Equity,Diluted EPS,Total Revenue,Net Income,EBITDA,\
    Long Term Investment,Interest Expense,Return on Equity,Cash and Cash Equivalents ,Quick Ratio,Current Ratio  "+ data 
    
    if type1=='Bard':
        response=palmresponse(prompt)
    elif type1=='ChatGpt':
        response=gpt_outcome_data(prompt)
    return response
#

# %%
#function to generate prompt for different companies
def bardoutcome_investment1(company,data,type1):
    #add your prompt here
    prompt ="Is "+company+" a good company to invest in 2023 and how much % return someone can expect to get on $1000. \
    Use this data to analyze - Total Debt,Total Equity,Total Debt on Total Equity,Diluted EPS,Total Revenue,Net Income,EBITDA,\
    Long Term Investment,Interest Expense,Return on Equity,Cash and Cash Equivalents ,Quick Ratio,Current Ratio  "+ data[0] + data[1] + data[2] 
    
    if type1=='Bard':
        response=palmresponse(prompt)
    elif type1=='ChatGpt':
        response=gpt_outcome_data(prompt)
    return response
#

# %%
def sentiment_analysis(t1):
    prompt ="perform sentiment analysis of this text"+ str(t1) +"in single keyword as positive, negative or neutral"
    response = str(palmresponse(prompt))    
    if response == 'positive':
        return "Received " + response +" sentiment analysis from Bard",'Yes'
    elif response == 'negative':
        return "Received " + response +" sentiment analysis from Bard",'No'
    if response == 'neutral':
        return "Received " + response +" sentiment analysis from Bard",'Maybe'

# %%
#function to remove stopwords and generate bag of words
import nltk

def remove_stopwords(string):
    # Create a set of stopwords.
    stopwords = set(nltk.corpus.stopwords.words('english'))
    # Split the string into a list of words.
    words = str(string).split()
    # Remove the stopwords from the list of words.
    filtered_words = [word for word in words if word not in stopwords]
    # Join the filtered words back into a string.
    filtered_string = ' '.join(filtered_words)
    # Return the filtered string.
    return filtered_string

# %%
#empty dataframe to store bard result
final_data=pd.DataFrame(columns=['Company_name','dates','bard_company_info','bard_recommendation', "Investment_Y/N","Sentiment_of_investment","Latest_news",
                                 "sentiment_of_latest_news","past_news","highest_match","sentiment_of_match"],index=range(15))

# %%
#empty dataframe to store chatgpt result
final_datagpt=pd.DataFrame(columns=['Company_name','dates','bard_company_info','bard_recommendation', "Investment_Y/N","Sentiment_of_investment","Latest_news",
                                 "sentiment_of_latest_news","past_news","highest_match","sentiment_of_match"],index=range(15))

# %%
def complete_process(company_name,dates,type1):  
    
    bard_data=bardoutcome_data(company_name,type1)
    bard_outcome=bardoutcome_investment(company_name, bard_data,type1)
    
    sentiment_bard, flag=sentiment_analysis(bard_outcome)
    prompt ="latest wall street journal news for "+company_name +" in ** format"
    t1=palmresponse(prompt)
    t1=t1.split("**")[2]
    s1,flag1=sentiment_analysis(t1)
    
    from io import StringIO
    df = pd.read_csv(StringIO(palmresponse("pull " + company_name +" news from wall street journal only for these dates " + \
                                           dates +  " in tabular format")), sep="|")
    df=df.iloc[1:,1:-1]
    
    from sklearn.feature_extraction.text import TfidfVectorizer
    vectorizer = TfidfVectorizer(ngram_range=(1,2),max_features=50)

    # Transform the texts into TF-IDF vectors.
    hist_vector = vectorizer.fit_transform(df.iloc[:,1].apply(lambda x: remove_stopwords(x)))
    current_vector=vectorizer.transform(pd.Series(t1).apply(lambda x: remove_stopwords(x)))
    from sklearn.metrics.pairwise import cosine_similarity
    cos=cosine_similarity( hist_vector,current_vector)
    index_highest=pd.DataFrame(cos).idxmax()[0]
    s2=sentiment_analysis(df.iloc[index_highest,2])
    
    return bard_data, bard_outcome, flag,sentiment_bard, t1,s1,df.iloc[:,1],df.iloc[index_highest,1],s2

# %% [markdown]
# List of company names and important dates associated to those companies

# %%
list_companies=['Apple','Amazon','Tesla','Meta','Pfizer','Moderna','Netflix','LVMH','Royal caribbean cruises ltd',
                'Zillow','Walt disney co','Comcast','AT&T','Google','Salesforce']

# %%
dates=['August 15 2022, July 28 2023, October 30 2020, January 5 2023',
       'March 29 2022,July 31 2023,November 2 ,2020, January 5 2023',
          ' November 4 2021,April 4 2022,Friday October 30 2020,Tuesday January 3 2023',
       '9/7/21,7/28/23,11/2/22,3/11/22',
           'November 9 2020 - November 25 2020,November 2 2021 - November 5 2021,May 22 2023 - May 31 2023',
          'June 18 2021 - July 28 2021,November 11 2021 - November 29 2021,January 10 2022 - January 27 2022',
        'September 17 2021 - October 15 2021, April 8 2022 - May 6 2022,April 28 2023 - June 30 2023',
       'October 16 2020 - November 13 2020,August 6 2021 - September 10 2021,Septmeber 09 2022 - November 04 2022',
       'Feburary 14 2020 - March 13 2020,April 24 2022 - May 13 2022,September 30 2022 - October 24 2022',
       'Feburary 21 2020 - March 20 2020,Janurary 29 2021 - Feb 12 2021,October 29 2021 - November 26 2021',
       'October 30 2020 - November 30 2020,March 18 2022 - April 22 2022,December 30 2022 - Janurary 27 2023',
       'Feburary 14 2020 - March 20 2020,September 3 2021 - October 1 2021,September 9 2022 - October 7 2022',
       'March 6 2020 - April 3 2020, October 22 2021 - December 10 2021,August 12 2022 - September 30 2022',
       'July 31 2020 - August 28 2020,Janurary 5 2021 - Feburary 5 2021,March 25 2022 - May 27 2022',
       'November 12 2021 - December 3 2021,December 16 2021 - January 20 2023,Feburary 14 2020- March 13 2020'
      ]

# %%
final_data.iloc[:,0]=list_companies
final_data.iloc[:,1]=dates

# %%
for i in range(0,final_data.iloc[:,0].shape[0]):
    print(final_data.iloc[i,0])
    final_data.iloc[i,2:]=complete_process(final_data.iloc[i,0],final_data.iloc[i,1],'Bard')
# Out:
# Apple
# Amazon
# Tesla
# Meta
# Pfizer
# Moderna
# Netflix
# LVMH
# Royal caribbean cruises ltd
# Zillow
# Walt disney co
# Comcast
# AT&T
# Google
# Salesforce

# %%
final_data.head()
# Out:
#   Company_name                                              dates  \
# 0        Apple  August 15 2022, July 28 2023, October 30 2020,...
# 1       Amazon  March 29 2022,July 31 2023,November 2 ,2020, J...
# 2        Tesla   November 4 2021,April 4 2022,Friday October 3...
# 3         Meta                     9/7/21,7/28/23,11/2/22,3/11/22
# 4       Pfizer  November 9 2020 - November 25 2020,November 2 ...
#
#                                    bard_company_info  \
# 0  | Field | FY2020 | FY2021 | FY2022 |\n|---|---...
# 1  | Field | FY2020 | FY2021 | FY2022 |\n|---|---...
# 2  | Field | FY2020 | FY2021 | FY2022 |\n|---|---...
# 3  | Field | FY2020 | FY2021 | FY2022 |\n|---|---...
# 4  | Field | FY2020 | FY2021 | FY2022 |\n|---|---...
#
#                                  bard_recommendation Investment_Y/N  \
# 0  Yes, Apple is a good company to invest in 2023...            Yes
# 1  Based on the data, Amazon is a good company to...            Yes
# 2  Based on the financial data from 2020 to 2022,...            Yes
# 3  Based on the data, Meta is a good company to i...            Yes
# 4  Pfizer is a good company to invest in 2023. Th...            Yes
#
#                           Sentiment_of_investment  \
# 0  Received positive sentiment analysis from Bard
# 1  Received positive sentiment analysis from Bard
# 2  Received positive sentiment analysis from Bard
# 3  Received positive sentiment analysis from Bard
# 4  Received positive sentiment analysis from Bard
#
#                                          Latest_news  \
# 0  Apple stock falls after company warns of suppl...
# 1             Amazon Stock Soars After Earnings Beat
# 2  Tesla stock falls after CEO Elon Musk says he ...
# 3               Meta stock falls after earnings miss
# 4             Pfizer Shares Rise After Earnings Beat
#
#                          sentiment_of_latest_news  \
# 0  Received negative sentiment analysis from Bard
# 1  Received positive sentiment analysis from Bard
# 2  Received negative sentiment analysis from Bard
# 3  Received negative sentiment analysis from Bard
# 4  Received positive sentiment analysis from Bard
#
#                                            past_news  \
# 0  1     Apple to Release New MacBook Pro with M2...
# 1  1     Amazon to raise Prime membership price b...
# 2  1           **Tesla Stock Soars After Earnings...
# 3  1               Meta Platforms to Change Name ...
# 4  1     Pfizer says its COVID-19 vaccine is more...
#
#                                        highest_match  \
# 0                     Apple Announces New iPhone 13
# 1             Amazon to launch its own electric car
# 2   **Tesla Stock Drops After Elon Musk Smokes We...
# 3             Meta Platforms to Change Name to Meta
# 4   Pfizer shares surge 13% after company says it...
#
#                                   sentiment_of_match
# 0  (Received positive sentiment analysis from Bar...
# 1  (Received positive sentiment analysis from Bar...
# 2  (Received negative sentiment analysis from Bar...
# 3  (Received positive sentiment analysis from Bar...
# 4  (Received positive sentiment analysis from Bar...

# %% [markdown]
# ChatGPT results

# %%
final_datagpt.iloc[:,0]=list_companies
final_datagpt.iloc[:,1]=dates

# %%
for i in range(14,15):
    print(final_datagpt.iloc[i,0])
    final_datagpt.iloc[i,2:]=complete_process(final_data.iloc[i,0],final_data.iloc[i,1],'ChatGpt')
# Out:
# Salesforce

# %%
final_datagpt[['Company_name','bard_company_info','bard_recommendation', "Investment_Y/N","Sentiment_of_investment"]]
# Out:
#                    Company_name  \
# 0                         Apple
# 1                        Amazon
# 2                         Tesla
# 3                          Meta
# 4                        Pfizer
# 5                       Moderna
# 6                       Netflix
# 7                          LVMH
# 8   Royal caribbean cruises ltd
# 9                        Zillow
# 10               Walt disney co
# 11                      Comcast
# 12                         AT&T
# 13                       Google
# 14                   Salesforce
#
#                                     bard_company_info  \
# 0   Google Finance\n\n2020\n\nTotal Debt: $102.21B...
# 1   financial metrics:\nAmazon\nFY 2020 - FY 2022\...
# 2   Google Finance:\nFY 2020:\nTotal Debt: $14.53B...
# 3   Google Finance:\n\nMetafrom FY 2020-2022\n\nTo...
# 4   PFIZER- FY 2020-2022\n\nTotal Debt:\nFY2020- $...
# 5   Moderna Inc.\n\nFinancial Year:  2020\n\nTotal...
# 6   FY 2020\n\nTotal Debt: $10.9 billion\nTotal Eq...
# 7   Total debt (2020-2022):\n\nGoogle Finance: €78...
# 8   Royal Caribbean Cruises Ltd (RCL)\n\nFY2020\nT...
# 9                                                 NaN
# 10  Total Debt:\nFY 2020: 97.74B\nFY 2021: 97.20B\...
# 11  Comcast FY 2020:\nTotal Debt: $119.86Bd\nTotal...
# 12  AT&T (NYSE:T)\nFY2020\nTotal Debt:\t$186.78B\n...
# 13  Google Financials (FY2020-FY2022)\n\nTotal Deb...
# 14  FY 2020 (in millions USD)\nTotal Debt: 7,817 \...
#
#                                   bard_recommendation Investment_Y/N  \
# 0   2023\n\nTotal Debt: $131.48B\nTotal Equity: $1...            Yes
# 1   Amazon is a good company to invest in 2023 as ...            Yes
# 2   Tesla has become a highly profitable company a...            Yes
# 3   It is difficult to accurately predict how much...             No
# 4   Based on the above data, it appears that Pfize...            Yes
# 5   There is potential for investing in Moderna In...          Maybe
# 6   Based on the data provided, it does appear tha...            Yes
# 7   Yes, LVMH is a good company to invest in in 20...            Yes
# 8   Based on the data given for the past three yea...            Yes
# 9                                                 NaN            NaN
# 10  It is difficult to make a definite conclusion ...            Yes
# 11  Based on the financial data of Comcast from FY...            Yes
# 12  Based on the data provided, AT&T is likely to ...            Yes
# 13  Based on the data provided, Google looks like ...            Yes
# 14  It is difficult to predict whether Salesforce ...            Yes
#
#                            Sentiment_of_investment
# 0   Received positive sentiment analysis from Bard
# 1   Received positive sentiment analysis from Bard
# 2   Received positive sentiment analysis from Bard
# 3   Received negative sentiment analysis from Bard
# 4   Received positive sentiment analysis from Bard
# 5    Received neutral sentiment analysis from Bard
# 6   Received positive sentiment analysis from Bard
# 7   Received positive sentiment analysis from Bard
# 8   Received positive sentiment analysis from Bard
# 9                                              NaN
# 10  Received positive sentiment analysis from Bard
# 11  Received positive sentiment analysis from Bard
# 12  Received positive sentiment analysis from Bard
# 13  Received positive sentiment analysis from Bard
# 14  Received positive sentiment analysis from Bard

# %%
data_invest= [1 if response == "Yes" else -1 for response in final_data['Investment_Y/N']]
final_data['Investment']=data_invest

data_invest= [1 if response == "Yes" else -1 for response in final_datagpt['Investment_Y/N']]
final_datagpt['Investment']=data_invest

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))
# Create a bar chart with labels


ax.bar(final_data[final_data['Investment']>0]['Company_name'],final_data[final_data['Investment']>0]['Investment'], color='green', alpha=0.8)

ax.bar(final_data[final_data['Investment']<0]['Company_name'],final_data[final_data['Investment']<0]['Investment'], color='red', alpha=0.8)

ax.set_title('Investment Portfolio using Bard')
ax.set_xlabel('Company Names')
ax.set_ylabel('Investment return (Yes/No)')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))
# Create a bar chart with labels


ax.bar(final_datagpt[final_datagpt['Investment']>0]['Company_name'],final_datagpt[final_datagpt['Investment']>0]['Investment'], color='green', alpha=0.8)

ax.bar(final_datagpt[final_datagpt['Investment']<0]['Company_name'],final_datagpt[final_datagpt['Investment']<0]['Investment'], color='red', alpha=0.8)

ax.set_title('Investment Portfolio using ChatGPT')
ax.set_xlabel('Company Names')
ax.set_ylabel('Investment return (Yes/No)')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
final_datagpt.to_excel("final_data_generated_chatgpt_analysis.xlsx")

# %%
final_data.to_excel("final_data_generated_bybard_analysis.xlsx")

# %% [markdown]
# ## Case 2- Using financial data captured from Capital IQ and passing to Bard for analysis

# %%
import pandas as pd
data= pd.read_excel("C://Users//HP NOTES//Mini 2//exp learning//hackathon//Financial_DatabyCapitalIQ.xlsx")

# %%
data=data.iloc[:,0:-2]

# %%
data
# Out:
#                         Company  Year  Total Debt  Total Equity  \
# 0                        Amazon  2020  104740.000     93404.000
# 1                        Amazon  2021  139757.000    138245.000
# 2                        Amazon  2022  169938.000    146043.000
# 3                         Apple  2020  122278.000     65339.000
# 4                         Apple  2021  136522.000     63090.000
# 5                         Apple  2022  132480.000     50672.000
# 6                         Tesla  2020    8571.000     23679.000
# 7                         Tesla  2021    4254.000     31583.000
# 8                         Tesla  2022    1029.000     45898.000
# 9                          Meta  2020   10324.000    101054.000
# 10                         Meta  2021   10654.000    128290.000
# 11                         Meta  2022   13873.000    124879.000
# 12                       Pfizer  2020   53449.000     63446.000
# 13                       Pfizer  2021   41264.000     63473.000
# 14                       Pfizer  2022   41395.000     77463.000
# 15                      Moderna  2020     135.947      1174.810
# 16                      Moderna  2021     237.000      2561.000
# 17                      Moderna  2022     916.000     14145.000
# 18                      Netflix  2020   18510.826     11065.240
# 19                      Netflix  2021   18116.570     15849.248
# 20                      Netflix  2022   16931.564     20777.401
# 21                         LVMH  2020   37553.000     38829.000
# 22                         LVMH  2021   34544.000     48909.000
# 23                         LVMH  2022   35325.000     56604.000
# 24  Royal caribbean cruises ltd  2020   20140.249      8760.669
# 25  Royal caribbean cruises ltd  2021   21756.068      5085.556
# 26  Royal caribbean cruises ltd  2022   23993.957      2868.812
# 27                       Zillow  2020    2519.765      4741.816
# 28                       Zillow  2021    1604.000      5341.000
# 29                       Zillow  2022    1867.000      4482.000
# 30               Walt disney co  2020   62323.000     97512.000
# 31               Walt disney co  2021   58313.000    102224.000
# 32               Walt disney co  2022   52259.000    108378.000
# 33                      Comcast  2020  113386.000     93018.000
# 34                      Comcast  2021  107259.000     98009.000
# 35                      Comcast  2022  106765.000     82038.000
# 36                         AT&T  2020  182984.000    179240.000
# 37                         AT&T  2021  199225.000    183855.000
# 38                         AT&T  2022  164373.000    106457.000
# 39                       Google  2020   27872.000    222544.000
# 40                       Google  2021   28508.000    251635.000
# 41                       Google  2022   29977.000    256144.000
# 42                   Salesforce  2020   17098.000     33885.000
# 43                   Salesforce  2021   21252.000     41493.000
# 44                   Salesforce  2022   26492.000     58131.000
#
#     Total Debt on Total Equity  Diluted EPS  Total Revenue  Net Income  \
# 0                     1.121365     2.090000     386064.000   21331.000
# 1                     1.010937     3.240000     469822.000   33364.000
# 2                     1.163616    -0.270000     513983.000   -2722.000
# 3                     1.871440     3.280000     274515.000   57411.000
# 4                     2.163925     5.610000     365817.000   94680.000
# 5                     2.614462     6.110000     394328.000   99803.000
# 6                     0.361966     0.210000      31536.000     721.000
# 7                     0.134693     1.634081      53823.000    5519.000
# 8                     0.022419     3.621294      81462.000   12556.000
# 9                     0.102163    10.090000      85965.000   29146.000
# 10                    0.919238    13.770000     117929.000   39370.000
# 11                    0.933776     8.590000     116609.000   23200.000
# 12                    0.842433     1.180000      41651.000    9159.000
# 13                    0.650103     3.930000      81288.000   21979.000
# 14                    0.534384     5.470000     100330.000   31372.000
# 15                    0.115718    -1.960000        803.000    -747.000
# 16                    0.092542    28.290000      18471.000   12202.000
# 17                    0.064758    20.120000      19263.000    8362.000
# 18                    1.672881     6.080000      24996.056    2761.395
# 19                    1.143055    11.240000      29697.844    5116.228
# 20                    0.814903     9.950000      31615.550    4491.924
# 21                    0.967138     9.320000      44651.000    4702.000
# 22                    0.706291    23.890000      64215.000   12036.000
# 23                    0.624073    28.030000      79184.000   14084.000
# 24                    2.298940   -27.050000       2208.805   -5797.500
# 25                    4.278012   -20.890000       1532.133   -5260.500
# 26                    8.363726    -8.450000       8840.540   -2156.000
# 27                    0.531392     0.020000       1624.000    -162.000
# 28                    0.300318     0.390000       2132.000    -528.000
# 29                    0.416555    -0.360000       1958.000    -101.000
# 30                    0.639131    -1.570000      65388.000   -2864.000
# 31                    0.570443     1.110000      67418.000    1995.000
# 32                    0.482191     1.750000      82722.000    3145.000
# 33                    1.218968     2.280000     103564.000   10534.000
# 34                    1.094379     3.040000     116385.000   14159.000
# 35                    1.301409     1.210000     121427.000    5370.000
# 36                    1.020888    -0.430000     143050.000   -5176.000
# 37                    1.083598     3.032520     134038.000   20081.000
# 38                    1.544031    -1.100000     120741.000   -8524.000
# 39                    0.125242     2.930572     182527.000   40269.000
# 40                    0.113291     5.610049     257637.000   76033.000
# 41                    0.117031     4.557489     282836.000   59972.000
# 42                    0.184653     0.150000      17098.000     126.000
# 43                    0.154556     4.380000      21252.000    4072.000
# 44                    0.247200     1.480000      26492.000    1444.000
#
#         EBITDA Long Term Investment Interest Expense  Return on Equity  \
# 0    48079.000                 5700            -1647          0.274417
# 1    59312.000                 4003            -1809          0.288056
# 2    54169.000                 2815            -2367         -0.019149
# 3    77344.000               100887            -2873          0.736855
# 4   120233.000               127877            -2645          1.474433
# 5   130541.000               120805            -2931          1.754592
# 6     4273.000                    0             -748          0.054232
# 7     9434.000                    0             -371          0.204263
# 8    17439.000                    0             -191          0.324905
# 9    39533.000                 6234                0          0.254168
# 10   54720.000                 6775                0          0.311017
# 11   42241.000                 6201                0          0.185161
# 12   14455.000                20379            -1449          0.105043
# 13   32084.000                21348            -1291          0.318697
# 14   44024.000                14926            -1238          0.362221
# 15    -732.000                  639              -10         -0.399913
# 16   13528.000                 6843              -17          1.460792
# 17    9768.000                 8360              -29          0.502705
# 18    4700.999                    0           -767.5          0.296169
# 19    6402.921                    0           -765.6          0.380183
# 20    5969.513                    0           -706.2          0.245281
# 21   11496.000                 1786             -366          0.128377
# 22   19905.000                 2451             -242          0.289452
# 23   23908.000                 2175             -382          0.279605
# 24   -1711.000               17.271           -844.2         -0.537358
# 25   -2510.400                    -          -1291.8         -0.759845
# 26     630.472              115.049          -1364.2         -0.542082
# 27     272.000                    0             -138          0.001222
# 28     353.000                    0             -128          0.020232
# 29      21.000                    5              -35         -0.017917
# 30    9126.000                 3903            -1647         -0.024375
# 31    8603.000                 3935            -1546          0.025393
# 32   11995.000                 3218            -1549          0.033741
# 33   30593.000                 7820            -4588          0.120057
# 34   34621.000                 8082            -4281          0.144838
# 35   36445.000                 7250            -3896          0.054707
# 36   43610.000                 1780            -7727         -0.007985
# 37   49707.000                 6168            -6716          0.130962
# 38   44519.000                 4627            -6108         -0.047355
# 39   54903.000                20703             -135          0.189954
# 40   91144.000                29549             -346          0.320693
# 41   90771.000                30492             -357          0.236212
# 42    2598.000                 1963                -          0.005091
# 43    3301.000                 3909             -110          0.108042
# 44    3900.000                 4784             -216          0.028988
#
#     Cash and Cash Equivalents   Quick Ratio  Current Ratio
# 0                    42122.000     0.860109       1.050227
# 1                    36220.000     0.904629       1.135759
# 2                    53888.000     0.720933       0.944643
# 3                    38016.000     1.218194       1.363604
# 4                    34940.000     0.909659       1.074553
# 5                    23646.000     0.709407       0.879356
# 6                    19384.000     1.494034       1.875140
# 7                    17576.000     0.999391       1.375285
# 8                    16253.000     0.947283       1.531955
# 9                    17576.000     4.892130       5.051064
# 10                   16601.000     2.935273       3.154293
# 11                   14681.000     2.005624       2.203396
# 12                    1786.000     0.903472       1.352893
# 13                    1944.000     1.097185       1.398912
# 14                     416.000     0.884261       1.216455
# 15                    2624.000     1.370699       1.434951
# 16                    6848.000     1.539219       1.760626
# 17                    3205.000     2.342067       2.728214
# 18                    8205.550     1.129466       1.250557
# 19                    6027.804     0.804824       0.950625
# 20                    5147.176     0.888585       1.168390
# 21                   19963.000     1.004226       1.578837
# 22                    8021.000     0.596913       1.225517
# 23                    7300.000     0.570459       1.259867
# 24                    3684.474     0.868256       0.950326
# 25                    2701.770     0.424779       0.494156
# 26                    1935.005     0.285493       0.373828
# 27                    1703.130     4.415360       5.464072
# 28                    2315.000     0.748583       1.978361
# 29                    1466.000    12.718518      13.344444
# 30                   17914.000     1.149992       1.323832
# 31                   15959.000     0.943656       1.083019
# 32                   11615.000     0.834691       1.000859
# 33                   11740.000     0.805875       0.928635
# 34                    8711.000     0.705976       0.845270
# 35                    4749.000     0.624699       0.782658
# 36                    9740.000     0.527838       0.819824
# 37                   19223.000     0.341155       1.607530
# 38                    3701.000     0.345788       0.589393
# 39                   26465.000     2.957349       3.066755
# 40                   20945.000     2.785087       2.928113
# 41                   21879.000     2.222510       2.377994
# 42                    4145.000     0.951229       1.075311
# 43                    6195.000     1.114169       1.234713
# 44                    5464.000     0.930604       1.048742

# %%
#empty dataframe to store result
final_data_bard2=pd.DataFrame(columns=['Company_name','dates','bard_company_info','bard_recommendation', "Investment_Y/N","Sentiment_of_investment","Latest_news",
                                 "sentiment_of_latest_news","past_news","highest_match","sentiment_of_match"],index=range(15))

#empty dataframe to store result
final_data_gpt2=pd.DataFrame(columns=['Company_name','dates','bard_company_info','bard_recommendation', "Investment_Y/N","Sentiment_of_investment","Latest_news",
                                 "sentiment_of_latest_news","past_news","highest_match","sentiment_of_match"],index=range(15))

# %%
final_data_bard2.iloc[:,0]=list_companies
final_data_bard2.iloc[:,1]=dates

final_data_gpt2.iloc[:,0]=list_companies
final_data_gpt2.iloc[:,1]=dates

# %%
def complete_process1(company_name,dates,data,type1):
    
    x = data.to_string(header=False,
                  index=False).split('\n')
    vals = [','.join(ele.split()) for ele in x]
    #print(vals)   
    
    bard_outcome=bardoutcome_investment1(company_name, vals,type1)
    #print(bard_outcome)
    
    sentiment_bard, flag=sentiment_analysis(bard_outcome)
    #print(sentiment_bard)
    prompt ="latest wall street journal news for "+company_name +" in ** format"
    t1=palmresponse(prompt)
    #print(t1)
    #print("This is the latest news only headline in wall street journal for "+ company_name)
    
    t1=t1.split("**")[2]
    #print(t1)
    
    s1,flag1=sentiment_analysis(t1)
    #print(s1)
    
    from io import StringIO
    df = pd.read_csv(StringIO(palmresponse("pull " + company_name +" news from wall street journal only for these dates " + \
                                           dates +  " in tabular format")), sep="|")
    df=df.iloc[1:,1:-1]
    #print(df)
    
    from sklearn.feature_extraction.text import TfidfVectorizer
    vectorizer = TfidfVectorizer(ngram_range=(1,2),max_features=50)

    # Transform the texts into TF-IDF vectors.
    hist_vector = vectorizer.fit_transform(df.iloc[:,1].apply(lambda x: remove_stopwords(x)))
    #print(hist_vector)
    #print("hist_vector")
    current_vector=vectorizer.transform(pd.Series(t1).apply(lambda x: remove_stopwords(x)))
    #print(current_vector)
    from sklearn.metrics.pairwise import cosine_similarity
    cos=cosine_similarity( hist_vector,current_vector)
    index_highest=pd.DataFrame(cos).idxmax()[0]
    #print("sentiment analysis")
    s2=sentiment_analysis(df.iloc[index_highest,2])
    #print(index_highest)
    #print(s2)
    
    return vals, bard_outcome, flag,sentiment_bard, t1,s1,df.iloc[:,1],df.iloc[index_highest,1],s2

# %%
for i in range(0,final_data_bard2.iloc[:,0].shape[0]):
    print(final_data_bard2.iloc[i,0])
    final_data_bard2.iloc[i,2:]=complete_process1(final_data_bard2.iloc[i,0],final_data_bard2.iloc[i,1],data[data.iloc[:,0]==final_data_bard2.iloc[i,0]],'Bard')
# Out:
# Apple
# Amazon
# Tesla
# Meta
# Pfizer
# Moderna
# Netflix
# LVMH
# Royal caribbean cruises ltd
# Zillow
# Walt disney co
# Comcast
# AT&T
# Google
# Salesforce

# %%
final_data_bard2
# Out:
#                    Company_name  \
# 0                         Apple
# 1                        Amazon
# 2                         Tesla
# 3                          Meta
# 4                        Pfizer
# 5                       Moderna
# 6                       Netflix
# 7                          LVMH
# 8   Royal caribbean cruises ltd
# 9                        Zillow
# 10               Walt disney co
# 11                      Comcast
# 12                         AT&T
# 13                       Google
# 14                   Salesforce
#
#                                                 dates  \
# 0   August 15 2022, July 28 2023, October 30 2020,...
# 1   March 29 2022,July 31 2023,November 2 ,2020, J...
# 2    November 4 2021,April 4 2022,Friday October 3...
# 3                      9/7/21,7/28/23,11/2/22,3/11/22
# 4   November 9 2020 - November 25 2020,November 2 ...
# 5   June 18 2021 - July 28 2021,November 11 2021 -...
# 6   September 17 2021 - October 15 2021, April 8 2...
# 7   October 16 2020 - November 13 2020,August 6 20...
# 8   Feburary 14 2020 - March 13 2020,April 24 2022...
# 9   Feburary 21 2020 - March 20 2020,Janurary 29 2...
# 10  October 30 2020 - November 30 2020,March 18 20...
# 11  Feburary 14 2020 - March 20 2020,September 3 2...
# 12  March 6 2020 - April 3 2020, October 22 2021 -...
# 13  July 31 2020 - August 28 2020,Janurary 5 2021 ...
# 14  November 12 2021 - December 3 2021,December 16...
#
#                                     bard_company_info  \
# 0   [Apple,2020,122278.0,65339.0,1.871440,3.28,274...
# 1   [Amazon,2020,104740.0,93404.0,1.121365,2.09,38...
# 2   [Tesla,2020,8571.0,23679.0,0.361966,0.210000,3...
# 3   [Meta,2020,10324.0,101054.0,0.102163,10.09,859...
# 4   [Pfizer,2020,53449.0,63446.0,0.842433,1.18,416...
# 5   [Moderna,2020,135.947,1174.81,0.115718,-1.96,8...
# 6   [Netflix,2020,18510.826,11065.240,1.672881,6.0...
# 7   [LVMH,2020,37553.0,38829.0,0.967138,9.32,44651...
# 8   [Royal,caribbean,cruises,ltd,2020,20140.249,87...
# 9   [Zillow,2020,2519.765,4741.816,0.531392,0.02,1...
# 10  [Walt,disney,co,2020,62323.0,97512.0,0.639131,...
# 11  [Comcast,2020,113386.0,93018.0,1.218968,2.28,1...
# 12  [AT&T,2020,182984.0,179240.0,1.020888,-0.43000...
# 13  [Google,2020,27872.0,222544.0,0.125242,2.93057...
# 14  [Salesforce,2020,17098.0,33885.0,0.184653,0.15...
#
#                                   bard_recommendation Investment_Y/N  \
# 0   Based on the data, Apple is a good company to ...            Yes
# 1   No, Amazon is not a good company to invest in ...             No
# 2   Based on the data, Tesla is not a good company...             No
# 3   No, Meta is not a good company to invest in 20...             No
# 4   Pfizer is a good company to invest in 2023. Th...            Yes
# 5   Moderna is not a good company to invest in 202...             No
# 6   No, Netflix is not a good company to invest in...             No
# 7   No, LVMH is not a good company to invest in 20...             No
# 8   No, Royal Caribbean Cruises Ltd is not a good ...             No
# 9   No, Zillow is not a good company to invest in ...             No
# 10  No, Walt Disney Co is not a good company to in...             No
# 11  No, Comcast is not a good company to invest in...             No
# 12  AT&T is not a good company to invest in 2023. ...             No
# 13  No, Google is not a good company to invest in ...             No
# 14  Based on the data, Salesforce is a good compan...            Yes
#
#                            Sentiment_of_investment  \
# 0   Received positive sentiment analysis from Bard
# 1   Received negative sentiment analysis from Bard
# 2   Received negative sentiment analysis from Bard
# 3   Received negative sentiment analysis from Bard
# 4   Received positive sentiment analysis from Bard
# 5   Received negative sentiment analysis from Bard
# 6   Received negative sentiment analysis from Bard
# 7   Received negative sentiment analysis from Bard
# 8   Received negative sentiment analysis from Bard
# 9   Received negative sentiment analysis from Bard
# 10  Received negative sentiment analysis from Bard
# 11  Received negative sentiment analysis from Bard
# 12  Received negative sentiment analysis from Bard
# 13  Received negative sentiment analysis from Bard
# 14  Received positive sentiment analysis from Bard
#
#                                           Latest_news  \
# 0   Apple stock falls after company warns of suppl...
# 1              Amazon Stock Soars After Earnings Beat
# 2   Tesla stock falls after CEO Elon Musk says he ...
# 3                Meta stock falls after earnings miss
# 4              Pfizer Shares Rise After Earnings Beat
# 5       Moderna Stock Soars on Strong Earnings Report
# 6             Netflix Stock Falls After Earnings Miss
# 7          LVMH Stock Soars on Strong Earnings Report
# 8                  Royal Caribbean Cruises Ltd. (RCL)
# 9              Zillow Stock Falls After Earnings Miss
# 10                              Walt Disney Co. (DIS)
# 11          Comcast News from the Wall Street Journal
# 12               AT&T Stock Falls After Earnings Miss
# 13             Google Stock Soars After Earnings Beat
# 14         Salesforce stock falls after earnings miss
#
#                           sentiment_of_latest_news  \
# 0   Received negative sentiment analysis from Bard
# 1   Received positive sentiment analysis from Bard
# 2   Received negative sentiment analysis from Bard
# 3   Received negative sentiment analysis from Bard
# 4   Received positive sentiment analysis from Bard
# 5   Received positive sentiment analysis from Bard
# 6   Received negative sentiment analysis from Bard
# 7   Received positive sentiment analysis from Bard
# 8   Received positive sentiment analysis from Bard
# 9   Received negative sentiment analysis from Bard
# 10  Received positive sentiment analysis from Bard
# 11  Received positive sentiment analysis from Bard
# 12  Received negative sentiment analysis from Bard
# 13  Received positive sentiment analysis from Bard
# 14  Received negative sentiment analysis from Bard
#
#                                             past_news  \
# 0   1     Apple to Release New MacBook Pro with M2...
# 1   1     Amazon to raise Prime membership price b...
# 2   1           **Tesla Stock Soars After Earnings...
# 3   1               Meta Platforms to Change Name ...
# 4   1      Pfizer says its COVID-19 vaccine is mor...
# 5   1     Moderna Says Its COVID-19 Vaccine Is 94....
# 6   1              Netflix Stock Soars After Earni...
# 7   1               LVMH to Buy Tiffany for \$15.8...
# 8   1     Royal Caribbean Cruises to Cut 15% of Wo...
# 9   1                    Zillow to lay off 2,500 e...
# 10  1              Disney Stock Soars After Earnin...
# 11  1                  Comcast to buy Sky for \$39...
# 12  1                     AT&T to Lay Off 23,000 E...
# 13  1     **Google to invest $1 billion in artific...
# 14  1         Salesforce Acquires Slack for \$27.7...
#
#                                         highest_match  \
# 0                      Apple Announces New iPhone 13
# 1              Amazon to launch its own electric car
# 2    **Tesla Stock Drops After Elon Musk Smokes We...
# 3              Meta Platforms to Change Name to Meta
# 4    Pfizer shares surge 13% after company says it...
# 5    Moderna Says Its COVID-19 Vaccine Is 94.1% Ef...
# 6            Netflix Stock Falls After Earnings Miss
# 7           LVMH Profit Soars as Luxury Demand Soars
# 8    Royal Caribbean Cruises to Resume Cruises to ...
# 9                  Zillow to lay off 2,500 employees
# 10            Disney Shares Rise After Earnings Beat
# 11      Comcast unveils details of streaming service
# 12   AT&T Stock Falls as Coronavirus Raises Concerns
# 13   **Google acquires fitness company Fitbit for ...
# 14   Salesforce Stock Rises After Strong Q4 Earnings
#
#                                    sentiment_of_match
# 0   (Received positive sentiment analysis from Bar...
# 1   (Received positive sentiment analysis from Bar...
# 2   (Received negative sentiment analysis from Bar...
# 3   (Received positive sentiment analysis from Bar...
# 4   (Received positive sentiment analysis from Bar...
# 5   (Received positive sentiment analysis from Bar...
# 6   (Received negative sentiment analysis from Bar...
# 7   (Received positive sentiment analysis from Bar...
# 8   (Received positive sentiment analysis from Bar...
# 9   (Received negative sentiment analysis from Bar...
# 10  (Received positive sentiment analysis from Bar...
# 11  (Received positive sentiment analysis from Bar...
# 12  (Received negative sentiment analysis from Bar...
# 13  (Received positive sentiment analysis from Bar...
# 14  (Received positive sentiment analysis from Bar...

# %%
for i in range(0,final_data_gpt2.iloc[:,0].shape[0]):
    print(final_data_gpt2.iloc[i,0])
    final_data_gpt2.iloc[i,2:]=complete_process1(final_data_gpt2.iloc[i,0],final_data_gpt2.iloc[i,1],data[data.iloc[:,0]==final_data_gpt2.iloc[i,0]],'ChatGpt')

# %%
final_data_gpt2[['Company_name','bard_company_info','bard_recommendation', "Investment_Y/N","Sentiment_of_investment"]]
# Out:
#                    Company_name  \
# 0                         Apple
# 1                        Amazon
# 2                         Tesla
# 3                          Meta
# 4                        Pfizer
# 5                       Moderna
# 6                       Netflix
# 7                          LVMH
# 8   Royal caribbean cruises ltd
# 9                        Zillow
# 10               Walt disney co
# 11                      Comcast
# 12                         AT&T
# 13                       Google
# 14                   Salesforce
#
#                                     bard_company_info  \
# 0   [Apple,2020,122278.0,65339.0,1.871440,3.28,274...
# 1   [Amazon,2020,104740.0,93404.0,1.121365,2.09,38...
# 2   [Tesla,2020,8571.0,23679.0,0.361966,0.210000,3...
# 3   [Meta,2020,10324.0,101054.0,0.102163,10.09,859...
# 4   [Pfizer,2020,53449.0,63446.0,0.842433,1.18,416...
# 5   [Moderna,2020,135.947,1174.81,0.115718,-1.96,8...
# 6   [Netflix,2020,18510.826,11065.240,1.672881,6.0...
# 7   [LVMH,2020,37553.0,38829.0,0.967138,9.32,44651...
# 8   [Royal,caribbean,cruises,ltd,2020,20140.249,87...
# 9   [Zillow,2020,2519.765,4741.816,0.531392,0.02,1...
# 10  [Walt,disney,co,2020,62323.0,97512.0,0.639131,...
# 11  [Comcast,2020,113386.0,93018.0,1.218968,2.28,1...
# 12  [AT&T,2020,182984.0,179240.0,1.020888,-0.43000...
# 13  [Google,2020,27872.0,222544.0,0.125242,2.93057...
# 14  [Salesforce,2020,17098.0,33885.0,0.184653,0.15...
#
#                                   bard_recommendation Investment_Y/N  \
# 0   Apple is a good company to invest in 2023 base...            Yes
# 1   Amazon is generally considered to be a good co...            Yes
# 2   It is difficult to predict whether Tesla will ...          Maybe
# 3   It is difficult to ascertain with certainty wh...            Yes
# 4   Pfizer is a good company to invest in 2023. Th...            Yes
# 5   Moderna looks like a good company to invest in...            Yes
# 6   Netflix stock is an excellent long-term invest...            Yes
# 7   LVMH is a stable company with solid performanc...            Yes
# 8   It is difficult to say if Royal Caribbean Crui...          Maybe
# 9   It is difficult to determine if Zillow is a go...          Maybe
# 10  Walt Disney Co is a good company to invest in ...            Yes
# 11  Comcast could be a good company to invest in f...            Yes
# 12  AT&T has seen some financial improvements over...            Yes
# 13  Based on this data, it is difficult to make a ...          Maybe
# 14  There is no definitive answer to this question...            Yes
#
#                            Sentiment_of_investment
# 0   Received positive sentiment analysis from Bard
# 1   Received positive sentiment analysis from Bard
# 2    Received neutral sentiment analysis from Bard
# 3   Received positive sentiment analysis from Bard
# 4   Received positive sentiment analysis from Bard
# 5   Received positive sentiment analysis from Bard
# 6   Received positive sentiment analysis from Bard
# 7   Received positive sentiment analysis from Bard
# 8    Received neutral sentiment analysis from Bard
# 9    Received neutral sentiment analysis from Bard
# 10  Received positive sentiment analysis from Bard
# 11  Received positive sentiment analysis from Bard
# 12  Received positive sentiment analysis from Bard
# 13   Received neutral sentiment analysis from Bard
# 14  Received positive sentiment analysis from Bard

# %%
final_data_gpt2.to_excel("chatgpt_analysis_basedon_capitalIQ.xlsx")

# %%
final_data_bard2.to_excel("Bard_analysis_basedon_capitalIQ.xlsx")

# %%
data_invest= [1 if response == "Yes" else -1 for response in final_data_bard2['Investment_Y/N']]
final_data_bard2['Investment']=data_invest

data_invest= [1 if response == "Yes" else -1 for response in final_data_gpt2['Investment_Y/N']]
final_data_gpt2['Investment']=data_invest

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))
# Create a bar chart with labels


ax.bar(final_data_bard2[final_data_bard2['Investment']>0]['Company_name'],final_data_bard2[final_data_bard2['Investment']>0]['Investment'], color='green', alpha=0.8)

ax.bar(final_data_bard2[final_data_bard2['Investment']<0]['Company_name'],final_data_bard2[final_data_bard2['Investment']<0]['Investment'], color='red', alpha=0.8)


ax.set_title('Investment Portfolio')
ax.set_xlabel('Company Names')
ax.set_ylabel('Investment return (Yes/No)')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 6))
# Create a bar chart with labels


ax.bar(final_data_gpt2[final_data_gpt2['Investment']>0]['Company_name'],final_data_gpt2[final_data_gpt2['Investment']>0]['Investment'], color='green', alpha=0.8)

ax.bar(final_data_gpt2[final_data_gpt2['Investment']<0]['Company_name'],final_data_gpt2[final_data_gpt2['Investment']<0]['Investment'], color='red', alpha=0.8)


ax.set_title('Investment Portfolio')
ax.set_xlabel('Company Names')
ax.set_ylabel('Investment return (Yes/No)')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
